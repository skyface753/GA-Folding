# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Generation","AvgFitness","BestFitness","BesteFitnessOverAll","BestHydroContacts","BestOverlaps","HydroContactsOverAll","OverlapsOverAll","MutationRate","AnzahlMutationen","Diversity","BestFolding"]
df = pd.read_csv("Output/output.csv", usecols=columns)
print("Contents in csv file:", df)
# Plot Avg, Best, BesteFitnessOverAll in one plot based on Generation
df.plot(x="Generation", y=["AvgFitness","BestFitness","BesteFitnessOverAll"], title="Fitness", xlabel="Generation", ylabel="Fitness")
plt.show()
# Out:
# Contents in csv file:      Generation  AvgFitness  BestFitness  BesteFitnessOverAll  \
# 0             0    1.673117          5.0                  5.0
# 1             1    1.693406          7.0                  7.0
# 2             2    2.110302          7.0                  7.0
# 3             3    2.633682          9.0                  9.0
# 4             4    3.266600         10.0                 10.0
# ..          ...         ...          ...                  ...
# 196         196    8.733491         25.0                 27.0
# 197         197    8.928657         25.0                 27.0
# 198         198    9.065210         25.0                 27.0
# 199         199    9.093284         25.0                 27.0
# 200         200    8.979154         25.0                 27.0
#
#      BestHydroContacts  BestOverlaps  HydroContactsOverAll  OverlapsOverAll  \
# 0                    5             0                    86               56
# 1                    7             0                    86               56
# 2                    7             0                    86               56
# 3                    9             0                    87               56
# 4                   10             0                    87               56
# ..                 ...           ...                   ...              ...
# 196                 25             0                   112               56
# 197                 25             0                   112               56
# 198                 25             0                   112               56
# 199                 25             0                   112               56
# 200                 25             0                   112               56
#
#     MutationRate  AnzahlMutationen  Diversity  \
# 0           0,00                 0        200
# 1           0,03               320        200
# 2           0,03               425        194
# 3           0,03               423        193
# 4           0,03               432        197
# ..           ...               ...        ...
# 196         0,04               450        197
# 197         0,04               457        197
# 198         0,03               441        195
# 199         0,04               465        197
# 200         0,03               447        199
#
#                                            BestFolding
# 0    LFFRRLFRFLFFFFLRFFFRFLLFRRLLRLLRFFFFRRLLRRFFFF...
# 1    LFFRRLFRFLFFFFLRFFFRFLLFRRLRRLLFFFFFRRLLRRFFFF...
# 2    LFFRRLFRFLFFFFLRFFFRFLLFRRLRRLLFFFFFRRLLRRFFFF...
# 3    RRRFLLRLRRLLRFRLLFLRRLLFRRLFFRRFLLFFRRLLFRFRLL...
# 4    RRRFRLRLRRLLRFFLLFFRFLLFRRLRRLLFFFFFRRLLFRFRFF...
# ..                                                 ...
# 196  FRRFRFRFFRFLLFFLFFFFLRLLRRLRRFLRRLFFRFFFLLFFFF...
# 197  FRRFRFRFFRFLLFFLFFFFLRLLRRLRLFLRRLLFRFRFLRRFLF...
# 198  FRRFRFRFFRFLLFFLFFFFLRLLRRLRRFLRRLFFRFFFLLFFFF...
# 199  FRRFRFRFFRFLLFFLFFFFLRLLRRLRRFLRRLFLRFFFLLFFFF...
# 200  FRRFRFRFFRFLLFFLFFFFLRLLRRLRRFLRRLFFRFFFLLFFFF...
#
# [201 rows x 12 columns]
