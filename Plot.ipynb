# %%
# !make clean
# !make build
# !java -cp BuildedFile.jar HP
# Out:
# rm -rf *.class Helpers/*.class BuildedFile.jar
# rm -rf /tmp/ga/*
# rm -rf ./Output/*
# javac -d . *.java Helpers/*.java
# jar -cvf BuildedFile.jar *.class Helpers/*.class
# Manifest wurde hinzugefügt
# Examples.class wird hinzugefügt(ein = 610) (aus = 331)(45 % verkleinert)
# Folding$1.class wird hinzugefügt(ein = 760) (aus = 488)(35 % verkleinert)
# Folding.class wird hinzugefügt(ein = 7960) (aus = 4319)(45 % verkleinert)
# HP.class wird hinzugefügt(ein = 9628) (aus = 4994)(48 % verkleinert)
# Node.class wird hinzugefügt(ein = 1012) (aus = 489)(51 % verkleinert)
# Population.class wird hinzugefügt(ein = 6247) (aus = 3535)(43 % verkleinert)
# RandomSelector.class wird hinzugefügt(ein = 1199) (aus = 658)(45 % verkleinert)
# Helpers/Helpers$H_Richtung.class wird hinzugefügt(ein = 1154) (aus = 613)(46 % verkleinert)
# Helpers/Helpers$RelDir.class wird hinzugefügt(ein = 2088) (aus = 1074)(48 % verkleinert)
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Generation","AvgFitness","BestFitness","BesteFitnessOverAll","BestHydroContacts","BestOverlaps","HydroContactsOverAll","OverlapsOverAll","MutationRate","AnzahlMutationen","Diversity","BestFolding"]
df = pd.read_csv("Output/output.csv", usecols=columns)
print("Contents in csv file:", df)
# Plot Avg, Best, BesteFitnessOverAll in one plot based on Generation
df.plot(x="Generation", y=["AvgFitness","BestFitness","BesteFitnessOverAll"], title="Fitness", xlabel="Generation", ylabel="Fitness")
plt.show()
# Out:
# Contents in csv file:      Generation  AvgFitness  BestFitness  BesteFitnessOverAll  \
# 0             0    0.887148     2.333333             2.333333
# 1             1    0.863961     1.750000             2.333333
# 2             2    0.975308     1.750000             2.333333
# 3             3    1.055516     2.500000             2.500000
# 4             4    1.276983     2.500000             2.500000
# ..          ...         ...          ...                  ...
# 96           96    8.034930    12.000000            12.000000
# 97           97    8.240361    12.000000            12.000000
# 98           98    8.999357    12.000000            12.000000
# 99           99    8.464333    13.000000            13.000000
# 100         100    8.637142    12.000000            13.000000
#
#      BestHydroContacts  BestOverlaps  HydroContactsOverAll  OverlapsOverAll  \
# 0                    7             2                    41               45
# ...
